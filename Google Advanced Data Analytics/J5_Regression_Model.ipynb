# %% [markdown]
# # **Automatidata project**
# **Course 5 - Regression Analysis: Simplify complex data relationships**

# %% [markdown]
# The data consulting firm Automatidata has recently hired you as the newest member of their data analytics team. Their newest client, the NYC Taxi and Limousine Commission (New York City TLC), wants the Automatidata team to build a multiple linear regression model for ride durations based on a variety of variables. The team is getting closer to completing the project, having completed an initial plan of action, initial Python coding work, EDA, and A/B testing.
#
# The Automatidata team has reviewed the results of the A/B testing. Now it’s time to work on predicting the taxi/ride share trip durations. You’ve impressed your Automatidata colleagues with your hard work and attention to detail. The data team believes that you are ready to build the regression model and update the client New York City TLC about your progress.

# %% [markdown]
# # Course 5 End-of-course project: Build a multiple linear regression model
# <br/>
#
# **The purpose** of this project is to demostrate knowledge of EDA and multiple linear regression models
#
# **The goal** is to build a multiple linear regression model and evaluate the model
# <br/>
#
# **Part 1:** EDA & Checking Model Assumptions
# * What are some purposes of EDA before constructing a multiple linear regression model?
# _We can use EDA to find duplicate or missing values within the data. These can interfere with the model. We can further analyze the relationships and find outliers in our variables._
#
# **Part 2:** Model Building and evaluation
# * What resources do you find yourself using as you complete this stage?
# _Scatter plots and residual graphs show a lot about the dataset and the relationships that we want to capture in the final regression. Scaling is also an effective precursor to training a regression. Sometimes we can use Principle component analysis, but considering the number of variables here it is not necessary. Lastly, using r-squared as a measure of effective is particularly useful._
# **Part 3:** Interpreting Model Results
#
# * What key insights emerged from your model(s)?
# _Removing outliers had the greatest impact on model performance. Location data was also a strong predictor used in the regression. This makes sense since some areas are more congested than others. The time of day had predictive power for similar reasons._
# * What business recommendations do you propose based on the models built?
# _This model is very accurate at predicting the duration of the trip. This could be easily implemented and used by the company to estimate the how long drivers will be unavailable._
# <br/>

# %% [markdown]
# # Build a multiple linear regression model

# %% [markdown]
# ## PACE: **Plan**

# %% [markdown]
# ### Task 1. Imports and loading
# Import the packages that you've learned are needed for building linear regression models.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime
from datetime import date
from datetime import timedelta

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
lr=LinearRegression()

# %% [markdown]
# `Pandas` is used to load the NYC TLC dataset. As shown in this cell, the dataset has been automatically loaded in for you. You do not need to download the .csv file, or provide more code, in order to access the dataset and proceed with this lab. Please continue with this activity by completing the following instructions.

# %%
# Use this path to load the data
df0=pd.read_csv("TLC_Taxi_data.csv")

print("Data Loaded")
# Out:
# Data Loaded

# %% [markdown]
# ## PACE: **Analyze**

# %% [markdown]
# ### Task 2a. Explore data with EDA
#
# Analyze and discover data, looking for correlations, missing data, outliers, and duplicates.

# %% [markdown]
# Start with `.shape` and `.info()`.

# %%
# Make copy of original
df = df0.copy()

# Print the dataset's shape
print(df.shape)

# Display basic info about the dataset
df.info()
# Out:
# (22699, 18)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  object
#  3   tpep_dropoff_datetime  22699 non-null  object
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
#  14  tip_amount             22699 non-null  float64
#  15  tolls_amount           22699 non-null  float64
#  16  improvement_surcharge  22699 non-null  float64
#  17  total_amount           22699 non-null  float64
# dtypes: float64(8), int64(7), object(3)
# memory usage: 3.1+ MB

# %% [markdown]
# Use `.head()`.

# %%
df.head(5)
# Out:
#    Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0    24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1    35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2   106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3    38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4    30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           100           231             1         13.0    0.0      0.5
# 1           186            43             1         16.0    0.0      0.5
# 2           262           236             1          6.5    0.0      0.5
# 3           188            97             1         20.5    0.0      0.5
# 4             4           112             2         16.5    0.5      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount
# 0        2.76           0.0                    0.3         16.56
# 1        4.00           0.0                    0.3         20.80
# 2        1.45           0.0                    0.3          8.75
# 3        6.39           0.0                    0.3         27.69
# 4        0.00           0.0                    0.3         17.80

# %% [markdown]
# Create `trip_duration`.

# %%
# Convert `tpep_dropoff_datetime` to datetime format
df["drop_off_converted"] = pd.to_datetime(df["tpep_dropoff_datetime"], format="%m/%d/%Y %I:%M:%S %p")

# Convert `tpep_pickup_datetime` to datetime format
df["pick_up_converted"] = pd.to_datetime(df["tpep_pickup_datetime"], format="%m/%d/%Y %I:%M:%S %p")

# Display data types of `drop_off_converted`, `pick_up_converted`
print("Data type of drop_off_converted:", df["drop_off_converted"].dtype)
print("Data type of pick_up_converted:", df["pick_up_converted"].dtype)

# Calculate `trip_duration`
df["trip_duration"] = (df["drop_off_converted"] - df["pick_up_converted"])/np.timedelta64(1,"m")

df.head(10)
# Out:
# Data type of drop_off_converted: datetime64[ns]
# Data type of pick_up_converted: datetime64[ns]
#    Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0    24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1    35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2   106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3    38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4    30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
# 5    23345809         2   03/25/2017 8:34:11 PM   03/25/2017 8:42:11 PM
# 6    37660487         2   05/03/2017 7:04:09 PM   05/03/2017 8:03:47 PM
# 7    69059411         2   08/15/2017 5:41:06 PM   08/15/2017 6:03:05 PM
# 8     8433159         2   02/04/2017 4:17:07 PM   02/04/2017 4:29:14 PM
# 9    95294817         1   11/10/2017 3:20:29 PM   11/10/2017 3:40:55 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
# 5                6           2.30           1                  N
# 6                1          12.83           1                  N
# 7                1           2.98           1                  N
# 8                1           1.20           1                  N
# 9                1           1.60           1                  N
#
#    PULocationID  DOLocationID  ...  fare_amount  extra  mta_tax  tip_amount  \
# 0           100           231  ...         13.0    0.0      0.5        2.76
# 1           186            43  ...         16.0    0.0      0.5        4.00
# 2           262           236  ...          6.5    0.0      0.5        1.45
# 3           188            97  ...         20.5    0.0      0.5        6.39
# 4             4           112  ...         16.5    0.5      0.5        0.00
# 5           161           236  ...          9.0    0.5      0.5        2.06
# 6            79           241  ...         47.5    1.0      0.5        9.86
# 7           237           114  ...         16.0    1.0      0.5        1.78
# 8           234           249  ...          9.0    0.0      0.5        0.00
# 9           239           237  ...         13.0    0.0      0.5        2.75
#
#    tolls_amount  improvement_surcharge  total_amount  drop_off_converted  \
# 0           0.0                    0.3         16.56 2017-03-25 09:09:47
# 1           0.0                    0.3         20.80 2017-04-11 15:19:58
# 2           0.0                    0.3          8.75 2017-12-15 07:34:08
# 3           0.0                    0.3         27.69 2017-05-07 13:48:14
# 4           0.0                    0.3         17.80 2017-04-15 23:49:03
# 5           0.0                    0.3         12.36 2017-03-25 20:42:11
# 6           0.0                    0.3         59.16 2017-05-03 20:03:47
# 7           0.0                    0.3         19.58 2017-08-15 18:03:05
# 8           0.0                    0.3          9.80 2017-02-04 16:29:14
# 9           0.0                    0.3         16.55 2017-11-10 15:40:55
#
#     pick_up_converted trip_duration
# 0 2017-03-25 08:55:43     14.066667
# 1 2017-04-11 14:53:28     26.500000
# 2 2017-12-15 07:26:56      7.200000
# 3 2017-05-07 13:17:59     30.250000
# 4 2017-04-15 23:32:20     16.716667
# 5 2017-03-25 20:34:11      8.000000
# 6 2017-05-03 19:04:09     59.633333
# 7 2017-08-15 17:41:06     21.983333
# 8 2017-02-04 16:17:07     12.116667
# 9 2017-11-10 15:20:29     20.433333
#
# [10 rows x 21 columns]

# %% [markdown]
# Check for missing data and duplicates using `.isna()` and `.drop_duplicates()`.

# %%
# Check for duplicates
print("Shape of dataframe:", df.shape)
print("Shape of dataframe with duplicates dropped:", df.drop_duplicates().shape)

# Check for missing values in dataframe
print("Total count of missing values:", df.isna().sum().sum())

# Display missing values per column
print("Missing values per column:")
df.isna().sum()
# Out:
# Shape of dataframe: (22699, 21)
# Shape of dataframe with duplicates dropped: (22699, 21)
# Total count of missing values: 0
# Missing values per column:
# Unnamed: 0               0
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# drop_off_converted       0
# pick_up_converted        0
# trip_duration            0
# dtype: int64

# %% [markdown]
# Use `.describe()`.

# %%
df.describe()
# Out:
#          Unnamed: 0      VendorID  passenger_count  trip_distance  \
# count  2.269900e+04  22699.000000     22699.000000   22699.000000
# mean   5.675849e+07      1.556236         1.642319       2.913313
# std    3.274493e+07      0.496838         1.285231       3.653171
# min    1.212700e+04      1.000000         0.000000       0.000000
# 25%    2.852056e+07      1.000000         1.000000       0.990000
# 50%    5.673150e+07      2.000000         1.000000       1.610000
# 75%    8.537452e+07      2.000000         2.000000       3.060000
# max    1.134863e+08      2.000000         6.000000      33.960000
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean       1.043394    162.412353    161.527997      1.336887     13.026629
# std        0.708391     66.633373     70.139691      0.496211     13.243791
# min        1.000000      1.000000      1.000000      1.000000   -120.000000
# 25%        1.000000    114.000000    112.000000      1.000000      6.500000
# 50%        1.000000    162.000000    162.000000      1.000000      9.500000
# 75%        1.000000    233.000000    233.000000      2.000000     14.500000
# max       99.000000    265.000000    265.000000      4.000000    999.990000
#
#               extra       mta_tax    tip_amount  tolls_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000
# mean       0.333275      0.497445      1.835781      0.312542
# std        0.463097      0.039465      2.800626      1.399212
# min       -1.000000     -0.500000      0.000000      0.000000
# 25%        0.000000      0.500000      0.000000      0.000000
# 50%        0.000000      0.500000      1.350000      0.000000
# 75%        0.500000      0.500000      2.450000      0.000000
# max        4.500000      0.500000    200.000000     19.100000
#
#        improvement_surcharge  total_amount  trip_duration
# count           22699.000000  22699.000000   22699.000000
# mean                0.299551     16.310502      17.013777
# std                 0.015673     16.097295      61.996482
# min                -0.300000   -120.300000     -16.983333
# 25%                 0.300000      8.750000       6.650000
# 50%                 0.300000     11.800000      11.183333
# 75%                 0.300000     17.800000      18.383333
# max                 0.300000   1200.290000    1439.550000

# %% [markdown]
# Create a scatterplot to visualize the relationship between variables of interest.

# %%
# Create a scatterplot to visualize the relationship between variables of interest
sns.set(style='whitegrid')
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(8)
sns.regplot(x=df["trip_duration"], y=df["trip_distance"])
plt.ylim(0, 60)
plt.xlim(0,140)
plt.show()

# %% [markdown]
# Create a pairplot to visualize pairwise relationships between relevant variables.

# %%
sns.pairplot(df[['trip_distance', 'tip_amount', 'total_amount', 'trip_duration']])

# %% [markdown]
# ### Task 2b. Address any outliers

# %% [markdown]
# Use a boxplot to visualize any outliers.

# %%
# Create boxplot to visualize the outliers
g = sns.boxplot(data=df[["passenger_count","tip_amount","total_amount", "trip_duration"]], showfliers=True);
g.set_title("4 Variables with Outliers",fontsize=20)
# Out:
# Text(0.5, 1.0, '4 Variables with Outliers')

# %% [markdown]
# Use a boxplot to visualize the distribution of the data without outliers.

# %%
# Create boxplot to visualize distribution of data without outliers
g = sns.boxplot(data=df[["passenger_count","tip_amount","total_amount", "trip_duration"]], showfliers=False);
g.set_title("4 Variables without Outliers",fontsize=20)
# Out:
# Text(0.5, 1.0, '4 Variables without Outliers')

# %% [markdown]
# Remove outliers as needed.

# %%
# Compute the 25th and 75th percentile values in `trip_duration`
percentile25 = df["trip_duration"].quantile(0.25)
percentile75 = df["trip_duration"].quantile(0.75)

# Compute the interquartile range for `trip_duration`
iqr = percentile75 - percentile25

# Compute the upper limit for `trip_duration`
upper_limit = percentile75 + 1.5 * iqr
upper_limit
# Out:
# 35.983333333333334

# %%
# We can use the calculated values to remove outliers. Observations at the lower limit should be set to 0
df[df["trip_duration"] > 36] = 36
df[df["trip_duration"] < 0] = 0

# Display descriptive stats after removing outliers in `trip_duration`
df["trip_duration"].describe()
# Out:
# count    22699.000000
# mean        13.668828
# std          9.245373
# min          0.000000
# 25%          6.650000
# 50%         11.183333
# 75%         18.383333
# max         36.000000
# Name: trip_duration, dtype: float64

# %%
# Repeat the process for total amount
percentile25 = df["total_amount"].quantile(0.25)
percentile75 = df["total_amount"].quantile(0.75)

iqr = percentile75 - percentile25

upper_limit = percentile75 + 1.5 * iqr
upper_limit
# Out:
# 31.375

# %%
# We can use the calculated values to remove outliers. Observations at the lower limit should be set to 0
df[df["total_amount"] > 32] = 32
df[df["total_amount"] < 0] = 0

df["total_amount"].describe()
# Out:
# count    22699.000000
# mean        14.481228
# std          7.985722
# min          0.000000
# 25%          8.750000
# 50%         11.800000
# 75%         17.800000
# max         32.000000
# Name: total_amount, dtype: float64

# %% [markdown]
# ### Task 2c. Identify correlations

# %% [markdown]
# Next, code a correlation matrix to help determine most correlated variables.

# %%
# Create correlation matrix between each of the columns
df.corr(method="pearson")
# Out:
#                        Unnamed: 0  VendorID  passenger_count  trip_distance  \
# Unnamed: 0               1.000000 -0.481317        -0.477442      -0.477195
# VendorID                -0.481317  1.000000         0.991848       0.986482
# passenger_count         -0.477442  0.991848         1.000000       0.979487
# trip_distance           -0.477195  0.986482         0.979487       1.000000
# RatecodeID              -0.482017  0.998629         0.991264       0.987527
# PULocationID             0.246150 -0.526237        -0.521962      -0.528553
# DOLocationID             0.251366 -0.513196        -0.508229      -0.519552
# payment_type            -0.481182  0.997372         0.990162       0.986164
# fare_amount             -0.388059  0.815431         0.810410       0.888456
# extra                   -0.481992  0.998017         0.990620       0.987172
# mta_tax                 -0.482116  0.998691         0.991338       0.987662
# tip_amount              -0.477809  0.989050         0.981633       0.985290
# tolls_amount            -0.482132  0.998268         0.990931       0.987733
# improvement_surcharge   -0.482138  0.998690         0.991338       0.987656
# total_amount            -0.351186  0.737951         0.733307       0.822827
# trip_duration           -0.311006  0.676771         0.673047       0.750085
#
#                        RatecodeID  PULocationID  DOLocationID  payment_type  \
# Unnamed: 0              -0.482017      0.246150      0.251366     -0.481182
# VendorID                 0.998629     -0.526237     -0.513196      0.997372
# passenger_count          0.991264     -0.521962     -0.508229      0.990162
# trip_distance            0.987527     -0.528553     -0.519552      0.986164
# RatecodeID               1.000000     -0.525975     -0.513027      0.998668
# PULocationID            -0.525975      1.000000      0.344806     -0.525536
# DOLocationID            -0.513027      0.344806      1.000000     -0.512832
# payment_type             0.998668     -0.525536     -0.512832      1.000000
# fare_amount              0.816677     -0.457266     -0.456931      0.814424
# extra                    0.999239     -0.525978     -0.513363      0.997997
# mta_tax                  0.999911     -0.526041     -0.512991      0.998720
# tip_amount               0.990328     -0.521739     -0.510127      0.984290
# tolls_amount             0.999531     -0.526066     -0.513347      0.998334
# improvement_surcharge    0.999923     -0.526072     -0.513028      0.998723
# total_amount             0.739149     -0.418361     -0.421618      0.731241
# trip_duration            0.677597     -0.380025     -0.380787      0.675499
#
#                        fare_amount     extra   mta_tax  tip_amount  \
# Unnamed: 0               -0.388059 -0.481992 -0.482116   -0.477809
# VendorID                  0.815431  0.998017  0.998691    0.989050
# passenger_count           0.810410  0.990620  0.991338    0.981633
# trip_distance             0.888456  0.987172  0.987662    0.985290
# RatecodeID                0.816677  0.999239  0.999911    0.990328
# PULocationID             -0.457266 -0.525978 -0.526041   -0.521739
# DOLocationID             -0.456931 -0.513363 -0.512991   -0.510127
# payment_type              0.814424  0.997997  0.998720    0.984290
# fare_amount               1.000000  0.816151  0.816518    0.838561
# extra                     0.816151  1.000000  0.999326    0.989988
# mta_tax                   0.816518  0.999326  1.000000    0.990417
# tip_amount                0.838561  0.989988  0.990417    1.000000
# tolls_amount              0.817433  0.998916  0.999584    0.990104
# improvement_surcharge     0.816525  0.999326  0.999999    0.990414
# total_amount              0.980834  0.740575  0.739000    0.785228
# trip_duration             0.941852  0.677547  0.678033    0.708682
#
#                        tolls_amount  improvement_surcharge  total_amount  \
# Unnamed: 0                -0.482132              -0.482138     -0.351186
# VendorID                   0.998268               0.998690      0.737951
# passenger_count            0.990931               0.991338      0.733307
# trip_distance              0.987733               0.987656      0.822827
# RatecodeID                 0.999531               0.999923      0.739149
# PULocationID              -0.526066              -0.526072     -0.418361
# DOLocationID              -0.513347              -0.513028     -0.421618
# payment_type               0.998334               0.998723      0.731241
# fare_amount                0.817433               0.816525      0.980834
# extra                      0.998916               0.999326      0.740575
# mta_tax                    0.999584               0.999999      0.739000
# tip_amount                 0.990104               0.990414      0.785228
# tolls_amount               1.000000               0.999588      0.741070
# improvement_surcharge      0.999588               1.000000      0.738997
# total_amount               0.741070               0.738997      1.000000
# trip_duration              0.678686               0.677982      0.942795
#
#                        trip_duration
# Unnamed: 0                 -0.311006
# VendorID                    0.676771
# passenger_count             0.673047
# trip_distance               0.750085
# RatecodeID                  0.677597
# PULocationID               -0.380025
# DOLocationID               -0.380787
# payment_type                0.675499
# fare_amount                 0.941852
# extra                       0.677547
# mta_tax                     0.678033
# tip_amount                  0.708682
# tolls_amount                0.678686
# improvement_surcharge       0.677982
# total_amount                0.942795
# trip_duration               1.000000

# %% [markdown]
# Visualize a correlation heatmap of the data.

# %%
# Turn this table into a heatmap
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(method="pearson"), annot=True, cmap="Blues")
plt.title("Correlation heatmap", fontsize=18)
plt.show()

# %% [markdown]
# ## PACE: **Construct**

# %% [markdown]
# ### Task 3a. Select outcome variable and features

# %% [markdown]
# Set your Y and X variables. Y represents the outcome variable, and X represents the features.

# %%
# Set Y variable and remove it from X
Y = df[["trip_duration"]]
X = df.drop(columns="trip_duration")

X.head()
# Out:
#    Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0    24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1    35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2   106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3    38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4    30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           100           231             1         13.0    0.0      0.5
# 1           186            43             1         16.0    0.0      0.5
# 2           262           236             1          6.5    0.0      0.5
# 3           188            97             1         20.5    0.0      0.5
# 4             4           112             2         16.5    0.5      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0        2.76           0.0                    0.3         16.56
# 1        4.00           0.0                    0.3         20.80
# 2        1.45           0.0                    0.3          8.75
# 3        6.39           0.0                    0.3         27.69
# 4        0.00           0.0                    0.3         17.80
#
#     drop_off_converted    pick_up_converted
# 0  2017-03-25 09:09:47  2017-03-25 08:55:43
# 1  2017-04-11 15:19:58  2017-04-11 14:53:28
# 2  2017-12-15 07:34:08  2017-12-15 07:26:56
# 3  2017-05-07 13:48:14  2017-05-07 13:17:59
# 4  2017-04-15 23:49:03  2017-04-15 23:32:20

# %% [markdown]
# ### Task 3b. Pre-process data
#
# To help with processing time, consider dropping irrelevant and redundant columns.

# %%
# Pre-process data
columns_to_drop = ['tpep_pickup_datetime', 'tpep_dropoff_datetime',
                   'store_and_fwd_flag', 'passenger_count', 'VendorID',
                   'fare_amount', 'PULocationID', 'DOLocationID', 'total_amount',
                   'drop_off_converted', 'pick_up_converted']
X = X.drop(columns_to_drop, axis=1)
X = X.loc[:, ~X.columns.str.contains("Unnamed")]
X.head()
# Out:
#    trip_distance  RatecodeID  payment_type  extra  mta_tax  tip_amount  \
# 0           3.34           1             1    0.0      0.5        2.76
# 1           1.80           1             1    0.0      0.5        4.00
# 2           1.00           1             1    0.0      0.5        1.45
# 3           3.70           1             1    0.0      0.5        6.39
# 4           4.37           1             2    0.5      0.5        0.00
#
#    tolls_amount  improvement_surcharge
# 0           0.0                    0.3
# 1           0.0                    0.3
# 2           0.0                    0.3
# 3           0.0                    0.3
# 4           0.0                    0.3

# %% [markdown]
# Use `StandardScaler()` and `fit_transform()` to standardize the X variables.

# %%
# Standardize the X variables
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
print("X scaled:", X_scaled)
# Out:
# X scaled: [[-0.18151313 -0.33715766 -0.37322483 ... -0.18534559 -0.33822608
#   -0.33681081]
#  [-0.34881939 -0.33715766 -0.37322483 ... -0.05279377 -0.33822608
#   -0.33681081]
#  [-0.43573173 -0.33715766 -0.37322483 ... -0.32538018 -0.33822608
#   -0.33681081]
#  ...
#  [-0.49874318 -0.33715766 -0.26554074 ... -0.48038029 -0.33822608
#   -0.33681081]
#  [-0.28798075 -0.33715766 -0.37322483 ... -0.29865602 -0.33822608
#   -0.33681081]
#  [-0.31622726 -0.33715766 -0.37322483 ... -0.22917321 -0.33822608
#   -0.33681081]]

# %% [markdown]
# ### Task 3c. Build model

# %% [markdown]
# Create training and testing sets.

# %%
# Create training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y,  test_size=0.2, random_state=0)

# %% [markdown]
# Build and fit your model to the data.

# %%
# Build and fit your model to the data
lr=LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Task 3d. Evaluate model

# %% [markdown]
# Evaluate your model performance by calculating the residual sum of squares and the explained variance score (R^2). Calculate the Mean Absolute Error, Mean Squared Error, and the Root Mean Squared Error.

# %%
# Evaluate model performance using training data
r_sq = lr.score(X_train, Y_train)
print("Coefficient of determination:", r_sq)
Y_pred = lr.predict(X_train)
print("R^2:", r2_score(Y_train, Y_pred))
print("MAE:", mean_absolute_error(Y_train,Y_pred))
print("RMSE:",np.sqrt(mean_squared_error(Y_train, Y_pred)))
# Out:
# Coefficient of determination: 0.7452534633044858
# R^2: 0.7452534633044858
# MAE: 3.2207502925227547
# RMSE: 4.5859932427873025

# %%
# Evaluate model performance on testing data
r_sq_test = lr.score(X_test, Y_test)
print("Coefficient of determination:", r_sq_test)
Y_pred_test = lr.predict(X_test)
print("R^2:", r2_score(Y_test, Y_pred_test))
print("MAE:", mean_absolute_error(Y_test,Y_pred_test))
print("RMSE:",np.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# Coefficient of determination: 0.7385047347008926
# R^2: 0.7385047347008926
# MAE: 3.2347404963477007
# RMSE: 4.61036135956137

# %% [markdown]
# ## PACE: **Execute**

# %% [markdown]
# ### Task 4a. Results
#
# If the linear regression assumptions are met, the model results can be appropriately interpreted.
#
# Use the code cell below to get `actual`,`predicted`, and `residual` for the testing set, and store them as columns in a `results` dataframe.

# %%
# Print a sample of the results
results = pd.DataFrame(data={"actual": Y_test["trip_duration"], "predicted": Y_pred_test.ravel()})
results["residual"] = results["actual"] - results["predicted"]
results.head()
# Out:
#           actual  predicted  residual
# 5818   18.016667  15.655547  2.361120
# 18134  32.000000  32.000124 -0.000124
# 4655    5.883333   7.340598 -1.457264
# 7378   15.950000  18.320577 -2.370577
# 13914  11.900000  11.538481  0.361519

# %% [markdown]
# ### Task 4b. Visualize model results

# %% [markdown]
# Create a scatterplot to visualize `predicted` over `actual`.

# %%
# Use this table to create a scatterplot
sns.set(style='whitegrid')
f = plt.figure()
f.set_figwidth(8)
f.set_figheight(8)

# Change color based on residual
colors = abs(results["residual"])
cmap = plt.cm.get_cmap("viridis")

# Create a custom reversed colormap
cmap_reversed = mcolors.LinearSegmentedColormap.from_list("reversed_viridis", cmap(np.linspace(1, 0, 256)))

# Plot
sns.scatterplot(x="actual", y="predicted", hue=colors, palette=cmap_reversed, data=results)
sns.regplot(x="actual", y="predicted", data=results, scatter=False, line_kws={"color": "red"})

plt.legend(title="Residual", loc="upper right")
plt.ylim(0, 40)
plt.xlim(0, 40)
plt.title("Actual Vs Predicted Trip Durations with Residuals", fontsize=16)  # Increase the font size to 16
plt.ylabel("Predicted Trip Duration")
plt.xlabel("Actual Trip Duration")
plt.show()

# %% [markdown]
# Visualize the distribution of the `residuals`.

# %%
# See the distribution of residuals
plt.hist(results["residual"], bins=30)
plt.title("Distribution of the residuals")
plt.xlabel("residual value")
plt.ylabel("count")
plt.show()

# %% [markdown]
# Create a scatterplot of `residuals` over `predicted`.

# %%
# Create a scatterplot of `residuals` over `predicted`
sns.scatterplot(x="predicted", y="residual", data=results)
plt.axhline(0)
plt.title("Scatterplot of residuals over predicted values")
plt.xlabel("predicted value")
plt.ylabel("residual value")
plt.show()

# %% [markdown]
# ### Task 4c. Conclusion
#
# 1. What are the key takeaways from this notebook?
#     * Regressions can be a powerful tool to predict a continuous dependent variable, however considering the skew in the residuals, I believe a better model can be fit.
#     * We can use EDA to select which variables belong in the model and which should be removed.
